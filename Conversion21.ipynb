# %%
import pandas as pd

# %%
pd.read_csv("http://www.conversion21.com/Data/c21_content.csv")
# Out:
#           id  asset_id                                              title  \
# 0          2        54               Campaña de reciclaje de electrónicos
# 1          3        55      ¿Qué hacer cuando "se pierde" la información?
# 2         12        56  Solamente 11 empresas dedicadas al GPS en Méxi...
# 3         13        57   Banda ancha, determinante para la competitividad
# 4         14        58  Mil 800 mdd deja a México exportación de tecno...
# 5         15        59  Creative y Championship Gaming Series anuncian...
# 6         16        60  Nuevo estándar AVCHD de Pinnacle Systems para ...
# 7         17        61  "Urgente mejorar los niveles de protección de ...
# 8         18        62  Pinnacle Systems anuncia nuevas descargas para...
# 9         19        63                     2008: el año del PlayStation 3
# 10        20        64           Microsoft bajará precio de Windows Vista
# 11        21        65  Alarcón Irigoyen va a la Dirección General de ...
# ...

# %%
resinfo = pd.read_csv("http://www.conversion21.com/Data/c21_content.csv")

# %%
pd.read_csv("http://www.conversion21.com/Data/lydwv_k2_items.csv")
# Out:
#      id                             title  \
# 0   152                NASDAQ 2014 bubble
# 1   153       Key and Peele sketch comedy
# 2   154        Whitney Houston remembered
# 3   155       Tampa braces for Convention
# 4   156    Billy Corgan speaks on Freedom
# 5   157      Ron Paul the only true hope?
# 6   158   Facebook insiders lose millions
# 7   142         End the Fed movement wins
# 8   143       Gas prices take their toll
# 9   144             Obama's housing plan
# 10  145            Obama has a mac attack
# 11  146              Ron Paul on the road
# 12  147        Depeche Mode kick off tour
# 13  150              Madonna shocks crowd
# 14   94        Gas prices peak for summer
# 15   95     FED blamed for market bubbles
# 16   96     Apple's less than stunning Q1
# 17   97            China's economic boost
# 18   98               NASDAQ 2013 bubble
# 19   99         Geitner's New World Order
# 20  100        Facebook insiders millions
# ...

# %%
k2item = pd.read_csv("http://www.conversion21.com/Data/lydwv_k2_items.csv")

# %%
k2item.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 36 columns):
# id                     61 non-null int64
# title                  61 non-null object
# alias                  61 non-null object
# catid                  61 non-null int64
# published              61 non-null int64
# introtext              61 non-null object
# fulltext               61 non-null object
# video                  54 non-null object
# gallery                8 non-null object
# extra_fields           61 non-null object
# extra_fields_search    0 non-null float64
# created                61 non-null object
# created_by             61 non-null int64
# created_by_alias       0 non-null float64
# checked_out            61 non-null int64
# checked_out_time       61 non-null object
# modified               61 non-null object
# modified_by            61 non-null int64
# publish_up             61 non-null object
# publish_down           61 non-null object
# ...

# %%
resinfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11329 entries, 0 to 11328
# Data columns (total 34 columns):
# id                  11329 non-null int64
# asset_id            11329 non-null int64
# title               11328 non-null object
# alias               11328 non-null object
# title_alias         0 non-null float64
# introtext           11325 non-null object
# fulltext            11306 non-null object
# state               11329 non-null int64
# sectionid           11329 non-null int64
# mask                11329 non-null int64
# catid               11329 non-null int64
# created             11329 non-null object
# created_by          11329 non-null int64
# created_by_alias    2 non-null object
# modified            11329 non-null object
# modified_by         11329 non-null int64
# checked_out         11329 non-null int64
# checked_out_time    11329 non-null object
# publish_up          11329 non-null object
# publish_down        11329 non-null object
# ...

# %%
k2item.head()
# Out:
#     id                           title  \
# 0  152              NASDAQ 2014 bubble
# 1  153     Key and Peele sketch comedy
# 2  154      Whitney Houston remembered
# 3  155     Tampa braces for Convention
# 4  156  Billy Corgan speaks on Freedom
#
#                                     alias  catid  published  \
# 0     nasdaq-2013-bubble-prophecy-reality     42          1
# 1  key-and-peele-keep-sketch-comedy-alive     42          1
# 2  whitneys-death-no-suprise-for-insiders     42          1
# 3         tampa-braces-for-gop-convention     42          1
# 4      billy-corgan-speaks-out-on-liberty     42          1
#
#                                            introtext  \
# 0  <p>\r\nDolor donec sagittis sapien. Ante apten...
# 1  <p>\r\nDolor donec sagittis sapien. Ante apten...
# 2  <p>\r\nDolor donec sagittis sapien. Ante apten...
# 3  <p>Dolor donec sagittis sapien. Ante aptent fe...
# 4  <p>\r\nDolor donec sagittis sapien. Ante apten...
#
# ...

# %%
resinfo.head()
# Out:
#    id  asset_id                                              title  \
# 0   2        54               Campaña de reciclaje de electrónicos
# 1   3        55      ¿Qué hacer cuando "se pierde" la información?
# 2  12        56  Solamente 11 empresas dedicadas al GPS en Méxi...
# 3  13        57   Banda ancha, determinante para la competitividad
# 4  14        58  Mil 800 mdd deja a México exportación de tecno...
#
#                                                alias  title_alias  \
# 0                       campae-reciclaje-de-electros          NaN
# 1            iquacer-cuando-qse-pierdeq-la-informaci          NaN
# 2  solamente-11-empresas-dedicadas-al-gps-en-mco-...          NaN
# 3    banda-ancha-determinante-para-la-competitividad          NaN
# 4  mil-800-mdd-deja-a-mco-exportacie-tecnolog-de-...          NaN
#
#                                            introtext  \
# 0  <strong>Olivia Aguayo<br /><br /><img src="htt...
# 1  <p><strong>Gerardo Melgoza* </strong></p><p><i...
# ...

# %%
resinfo.catid.value_counts()
# Out:
# 19    2460
# 27    1927
# 15    1653
# 13    1453
# 20    1284
# 17     822
# 21     487
# 24     393
# 14     218
# 18     192
# 23     132
# 30     125
# 22      84
# 32      51
# 25      39
# 28       6
# 29       2
# 0        1
# Name: catid, dtype: int64
